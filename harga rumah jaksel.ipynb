# %%
import numpy as np
import pandas as pd

# %%
data_rumah = pd.read_csv("JAKSEL.csv")

# %%
datarumah = pd.DataFrame(data_rumah)

# %%
datarumah.dtypes
# Out:
# HARGA     int64
# LT        int64
# LB        int64
# JKT       int64
# JKM       int64
# GRS      object
# KOTA     object
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.scatter(datarumah['LT'],datarumah['HARGA'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
